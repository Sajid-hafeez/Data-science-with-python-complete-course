# %% [markdown]
# # Session 1: Introduction to Data Science & Python Environment
#
# ## Data Science with Python - 2025 Edition
#
# **Instructor:** [Your Name]
# **Session Duration:** 1 hour
# **Date:** August 4, 2025
#
# ---
#
# ## 📋 Session Agenda
#
# 1. **What is Data Science?**
# 2. **Python's Role in Data Science**
# 3. **Setting Up the Environment**
# 4. **Course Objectives & Project-Based Learning**
# 5. **Jupyter Notebook Walkthrough**
# 6. **Hands-on Practice**
#
# ---

# %% [markdown]
# ## 🔍 What is Data Science?
#
# Data Science is an **interdisciplinary field** that combines:
#
# - **Statistics & Mathematics** - for analysis and modeling
# - **Computer Science** - for programming and algorithms
# - **Domain Expertise** - for understanding business context
#
# ### The Data Science Process (CRISP-DM)
#
# 1. **Business Understanding** - Define objectives and requirements
# 2. **Data Understanding** - Collect and explore data
# 3. **Data Preparation** - Clean and transform data
# 4. **Modeling** - Apply statistical/ML techniques
# 5. **Evaluation** - Assess model performance
# 6. **Deployment** - Implement the solution
#
# ### Real-World Applications
#
# - **Netflix** - Recommendation systems
# - **Uber** - Dynamic pricing and route optimization
# - **Amazon** - Supply chain optimization
# - **Healthcare** - Disease prediction and drug discovery
# - **Finance** - Fraud detection and risk assessment

# %% [markdown]
# ## 🐍 Why Python for Data Science?
#
# ### Advantages of Python
#
# 1. **Easy to Learn** - Simple, readable syntax
# 2. **Rich Ecosystem** - Extensive libraries for data science
# 3. **Community Support** - Large, active community
# 4. **Versatility** - Web development, automation, ML, AI
# 5. **Industry Standard** - Widely adopted by companies
#
# ### Key Python Libraries for Data Science
#
# | Library | Purpose | Example Use Case |
# |---------|---------|------------------|
# | **NumPy** | Numerical computing | Mathematical operations on arrays |
# | **Pandas** | Data manipulation | Loading, cleaning, and analyzing data |
# | **Matplotlib** | Data visualization | Creating plots and charts |
# | **Seaborn** | Statistical visualization | Beautiful statistical plots |
# | **Scikit-learn** | Machine learning | Building predictive models |
# | **Jupyter** | Interactive computing | Creating notebooks like this one |

# %% [markdown]
# ## ⚙️ Setting Up Your Data Science Environment
#
# ### Option 1: Anaconda Distribution (Recommended)
#
# **Anaconda** is a complete data science platform that includes:
# - Python interpreter
# - 250+ pre-installed packages
# - Conda package manager
# - Jupyter Notebook/Lab
# - Spyder IDE
#
# **Installation Steps:**
# 1. Download from [anaconda.com](https://www.anaconda.com/products/distribution)
# 2. Run the installer (choose "Add to PATH" option)
# 3. Open Anaconda Navigator or Anaconda Prompt
#
# ### Option 2: VS Code + Python Extension
#
# **Visual Studio Code** with Python extension provides:
# - Excellent code editing features
# - Integrated terminal
# - Jupyter notebook support
# - Git integration
# - Extensions ecosystem
#
# ### Option 3: Google Colab (Cloud-based)
#
# **Google Colaboratory** offers:
# - No installation required
# - Free GPU/TPU access
# - Easy sharing and collaboration
# - Integration with Google Drive

# %% [markdown]
# ## 🎯 Course Objectives & Learning Outcomes
#
# ### By the end of this course, you will be able to:
#
# ✅ **Manipulate and analyze data** using Pandas
# ✅ **Create compelling visualizations** with Matplotlib and Seaborn
# ✅ **Build machine learning models** for classification and regression
# ✅ **Perform exploratory data analysis** to extract insights
# ✅ **Clean and preprocess messy datasets**
# ✅ **Work with real-world APIs and web data**
# ✅ **Complete a capstone project** from start to finish
#
# ### Project-Based Learning Approach
#
# Each session includes **hands-on projects** using real datasets:
# - Titanic survival prediction
# - Customer churn analysis
# - Retail sales analysis
# - Stock price time series
# - COVID-19 dashboard
# - Final capstone project

# %% [markdown]
# ## 📓 Jupyter Notebook Walkthrough
#
# ### What is Jupyter Notebook?
#
# Jupyter Notebook is an **interactive computing environment** that allows you to:
# - Combine code, text, and visualizations in one document
# - Execute code in small chunks (cells)
# - Share reproducible research and analysis
# - Support for 40+ programming languages
#
# ### Cell Types
#
# 1. **Code Cells** - Execute Python code
# 2. **Markdown Cells** - Write formatted text, equations, links
# 3. **Raw Cells** - Unformatted text (rarely used)
#
# ### Essential Keyboard Shortcuts
#
# | Shortcut | Action |
# |----------|--------|
# | `Shift + Enter` | Run cell and move to next |
# | `Ctrl + Enter` | Run cell and stay |
# | `A` | Insert cell above |
# | `B` | Insert cell below |
# | `DD` | Delete cell |
# | `M` | Change to Markdown cell |
# | `Y` | Change to Code cell |
#
# ### Magic Commands
#
# Jupyter provides special "magic" commands for enhanced functionality:

# %%
# List all available magic commands
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %code_wrap  %colors  %conda  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %mamba  %matplotlib  %micromamba  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %uv  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
# Time execution of a single line
# %timeit sum(range(100))
# Out:
# 534 ns ± 8.37 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
# Time execution of entire cell
# %%time
total = 0
for i in range(1000):
    total += i**2
print(f"Total: {total}")
# Out:
# UsageError: Line magic function `%%time` not found.

# %%
# Display current working directory
# %pwd
# Out:
# 'c:\\Users\\sajid\\OneDrive\\Desktop\\PROJECTS\\Data science with Python'

# %%
# List files in current directory
# %ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 2008-AD18
#
#  Directory of c:\Users\sajid\OneDrive\Desktop\PROJECTS\Data science with Python
#
# 08/04/2025  04:07 PM    <DIR>          .
# 08/04/2025  04:04 PM    <DIR>          ..
# 08/04/2025  04:04 PM             3,973 content.md
# 08/04/2025  04:07 PM                 0 Session_1_Introduction_to_Data_Science.ipynb
#                2 File(s)          3,973 bytes
#                2 Dir(s)  333,342,613,504 bytes free

# %% [markdown]
# ## 🛠️ Hands-on Practice: Your First Data Science Code
#
# Let's start with some basic Python operations that you'll use throughout the course:

# %% [markdown]
# ### 1. Importing Essential Libraries

# %%
# If you need to install these packages, uncomment and run these pip commands:
# pip install numpy pandas matplotlib seaborn
# pip install jupyter  # For Jupyter notebook support

# Import the fundamental libraries for data science
import numpy as np                 # Numerical computing
import pandas as pd                # Data manipulation
import matplotlib.pyplot as plt    # Basic plotting
import seaborn as sns             # Statistical visualization

# Set up plotting parameters
plt.style.use('seaborn-v0_8')     # Use seaborn style for better-looking plots
plt.rcParams['figure.figsize'] = (10, 6)  # Set default figure size

print("✅ Libraries imported successfully!")
print(f"NumPy version: {np.__version__}")
print(f"Pandas version: {pd.__version__}")
# Out:
# ✅ Libraries imported successfully!
# NumPy version: 2.3.1
# Pandas version: 2.3.0

# %% [markdown]
# ### 2. Working with NumPy Arrays

# %%
# Create a sample dataset using NumPy
np.random.seed(42)  # For reproducible results

# Generate sample data
sample_data = np.random.normal(50, 15, 1000)  # 1000 values, mean=50, std=15

print("Sample Statistics:")
print(f"Mean: {np.mean(sample_data):.2f}")
print(f"Standard Deviation: {np.std(sample_data):.2f}")
print(f"Min: {np.min(sample_data):.2f}")
print(f"Max: {np.max(sample_data):.2f}")
print(f"Shape: {sample_data.shape}")

# %% [markdown]
# ### 3. Creating Your First DataFrame

# %%
# Load a real dataset from GitHub - Titanic dataset
# This is one of the most famous datasets in data science for learning

# URL to the Titanic dataset on GitHub
url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'

try:
    # Load the dataset directly from GitHub
    df = pd.read_csv(url)
    
    print("✅ Dataset loaded successfully from GitHub!")
    print(f"Dataset: Titanic Passenger Data")
    print(f"Shape: {df.shape}")
    print(f"Columns: {list(df.columns)}")
    
    print("\n" + "="*50)
    print("First 5 rows:")
    display(df.head())
    
    print("\n" + "="*50)
    print("Dataset Description:")
    print("This dataset contains information about Titanic passengers including:")
    print("- PassengerId: Unique ID for each passenger")
    print("- Survived: Whether passenger survived (0=No, 1=Yes)")
    print("- Pclass: Passenger class (1st, 2nd, 3rd)")
    print("- Name: Passenger name")
    print("- Sex: Gender")
    print("- Age: Age in years")
    print("- SibSp: Number of siblings/spouses aboard")
    print("- Parch: Number of parents/children aboard")
    print("- Ticket: Ticket number")
    print("- Fare: Passenger fare")
    print("- Cabin: Cabin number")
    print("- Embarked: Port of embarkation (C=Cherbourg, Q=Queenstown, S=Southampton)")
    
except Exception as e:
    print(f"❌ Error loading dataset: {e}")
    print("Please check your internet connection or try again later.")
    
    # Fallback: Create a simple synthetic dataset if GitHub is not accessible
    print("\n🔄 Creating fallback synthetic dataset...")
    np.random.seed(42)
    n_passengers = 100
    
    fallback_data = {
        'PassengerId': range(1, n_passengers + 1),
        'Survived': np.random.choice([0, 1], n_passengers, p=[0.6, 0.4]),
        'Pclass': np.random.choice([1, 2, 3], n_passengers, p=[0.2, 0.3, 0.5]),
        'Sex': np.random.choice(['male', 'female'], n_passengers),
        'Age': np.random.normal(30, 12, n_passengers).round(1),
        'Fare': np.random.exponential(30, n_passengers).round(2)
    }
    
    df = pd.DataFrame(fallback_data)
    df['Age'] = df['Age'].clip(lower=0, upper=80)  # Realistic age range
    
    print("✅ Fallback dataset created successfully!")
    print(f"Shape: {df.shape}")
    display(df.head())
# Out:
# ✅ Dataset loaded successfully from GitHub!
# Dataset: Titanic Passenger Data
# Shape: (891, 12)
# Columns: ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']
#
# ...
# First 5 rows:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# ### 4. Basic Data Exploration

# %%
# Get basic information about the Titanic dataset
print("Dataset Info:")
print(df.info())

print("\n" + "="*50)
print("Summary Statistics for Numerical Columns:")
display(df.describe())

print("\n" + "="*30)
print("Survival Rate:")
if 'Survived' in df.columns:
    survival_rate = df['Survived'].mean()
    print(f"Overall survival rate: {survival_rate:.1%}")
    print(f"Passengers who survived: {df['Survived'].sum()}")
    print(f"Passengers who didn't survive: {len(df) - df['Survived'].sum()}")

print("\n" + "="*30)
print("Passenger Class Distribution:")
if 'Pclass' in df.columns:
    pclass_counts = df['Pclass'].value_counts().sort_index()
    print(pclass_counts)

print("\n" + "="*30)
print("Gender Distribution:")
if 'Sex' in df.columns:
    gender_counts = df['Sex'].value_counts()
    print(gender_counts)
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None
#
# ...
# Summary Statistics for Numerical Columns:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# ...

# %%
# Check for missing values
print("Missing Values Count:")
missing_values = df.isnull().sum()
print(missing_values)

print("\n" + "="*40)
print("Missing Values Percentage:")
missing_percentage = (df.isnull().sum() / len(df) * 100).round(2)
missing_df = pd.DataFrame({
    'Missing Count': missing_values,
    'Missing Percentage': missing_percentage
})
print(missing_df[missing_df['Missing Count'] > 0])

print("\n" + "="*30)
print("Data Types:")
print(df.dtypes)

print("\n" + "="*30)
print("Key Observations about Missing Data:")
if 'Age' in df.columns and df['Age'].isnull().sum() > 0:
    print(f"- Age has {df['Age'].isnull().sum()} missing values ({df['Age'].isnull().sum()/len(df)*100:.1f}%)")
if 'Cabin' in df.columns and df['Cabin'].isnull().sum() > 0:
    print(f"- Cabin has {df['Cabin'].isnull().sum()} missing values ({df['Cabin'].isnull().sum()/len(df)*100:.1f}%)")
if 'Embarked' in df.columns and df['Embarked'].isnull().sum() > 0:
    print(f"- Embarked has {df['Embarked'].isnull().sum()} missing values ({df['Embarked'].isnull().sum()/len(df)*100:.1f}%)")
print("- Missing data is common in real-world datasets and requires careful handling!")
# Out:
# Missing Values Count:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
#
# ...
# Missing Values Percentage:
#           Missing Count  Missing Percentage
# Age                 177               19.87
# Cabin               687               77.10
# Embarked              2                0.22
#
# ...
# Data Types:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object
#
# ...
# Key Observations about Missing Data:
# - Age has 177 missing values (19.9%)
# - Cabin has 687 missing values (77.1%)
# - Embarked has 2 missing values (0.2%)
# ...

# %% [markdown]
# ### 5. Your First Data Visualization

# %%
# Create visualizations for the Titanic dataset
plt.figure(figsize=(15, 10))

# Subplot 1: Age Distribution
plt.subplot(2, 3, 1)
if 'Age' in df.columns:
    # Remove missing values for visualization
    age_data = df['Age'].dropna()
    plt.hist(age_data, bins=20, color='skyblue', alpha=0.7, edgecolor='black')
    plt.title('Distribution of Passenger Ages')
    plt.xlabel('Age')
    plt.ylabel('Frequency')

# Subplot 2: Fare Distribution
plt.subplot(2, 3, 2)
if 'Fare' in df.columns:
    fare_data = df['Fare'].dropna()
    plt.hist(fare_data, bins=20, color='lightgreen', alpha=0.7, edgecolor='black')
    plt.title('Distribution of Ticket Fares')
    plt.xlabel('Fare')
    plt.ylabel('Frequency')

# Subplot 3: Passenger Class Distribution
plt.subplot(2, 3, 3)
if 'Pclass' in df.columns:
    pclass_counts = df['Pclass'].value_counts().sort_index()
    plt.bar(pclass_counts.index, pclass_counts.values, color='salmon', alpha=0.7)
    plt.title('Passengers by Class')
    plt.xlabel('Passenger Class')
    plt.ylabel('Number of Passengers')
    plt.xticks([1, 2, 3], ['1st Class', '2nd Class', '3rd Class'])

# Subplot 4: Gender Distribution
plt.subplot(2, 3, 4)
if 'Sex' in df.columns:
    gender_counts = df['Sex'].value_counts()
    plt.pie(gender_counts.values, labels=gender_counts.index, autopct='%1.1f%%', 
            colors=['lightblue', 'pink'], startangle=90)
    plt.title('Gender Distribution')

# Subplot 5: Survival Rate
plt.subplot(2, 3, 5)
if 'Survived' in df.columns:
    survival_counts = df['Survived'].value_counts()
    labels = ['Did not survive', 'Survived']
    plt.pie(survival_counts.values, labels=labels, autopct='%1.1f%%', 
            colors=['lightcoral', 'lightgreen'], startangle=90)
    plt.title('Survival Rate')

# Subplot 6: Embarkation Port
plt.subplot(2, 3, 6)
if 'Embarked' in df.columns:
    embarked_counts = df['Embarked'].value_counts()
    plt.bar(embarked_counts.index, embarked_counts.values, color='gold', alpha=0.7)
    plt.title('Embarkation Ports')
    plt.xlabel('Port')
    plt.ylabel('Number of Passengers')
    # Add port names for clarity
    port_names = {'S': 'Southampton', 'C': 'Cherbourg', 'Q': 'Queenstown'}
    current_labels = plt.gca().get_xticklabels()
    new_labels = [port_names.get(label.get_text(), label.get_text()) for label in current_labels]
    plt.gca().set_xticklabels(new_labels, rotation=45)

plt.tight_layout()
plt.show()

print("🎉 Congratulations! You've created your first real-world data visualizations!")
print("📊 These charts show the distribution of various features in the Titanic dataset.")
print("💡 Notice how real data often has interesting patterns and missing values!")
# Out:
# C:\Users\sajid\AppData\Local\Temp\ipykernel_11084\1012909538.py:62: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plt.gca().set_xticklabels(new_labels, rotation=45)
# 🎉 Congratulations! You've created your first real-world data visualizations!
# 📊 These charts show the distribution of various features in the Titanic dataset.
# 💡 Notice how real data often has interesting patterns and missing values!

# %% [markdown]
# ### 6. Basic Data Analysis

# %%
# Analyze survival patterns in the Titanic dataset
print("Survival Analysis:")

if 'Survived' in df.columns and 'Sex' in df.columns:
    print("\n1. Survival Rate by Gender:")
    gender_survival = df.groupby('Sex')['Survived'].agg(['count', 'sum', 'mean']).round(3)
    gender_survival.columns = ['Total', 'Survived', 'Survival_Rate']
    print(gender_survival)

if 'Survived' in df.columns and 'Pclass' in df.columns:
    print("\n2. Survival Rate by Passenger Class:")
    class_survival = df.groupby('Pclass')['Survived'].agg(['count', 'sum', 'mean']).round(3)
    class_survival.columns = ['Total', 'Survived', 'Survival_Rate']
    class_survival.index = ['1st Class', '2nd Class', '3rd Class']
    print(class_survival)

if 'Age' in df.columns:
    print("\n3. Age Statistics by Survival:")
    age_survival = df.groupby('Survived')['Age'].agg(['count', 'mean', 'median', 'std']).round(2)
    age_survival.index = ['Did not survive', 'Survived']
    print(age_survival)

if 'Fare' in df.columns and 'Survived' in df.columns:
    print("\n4. Fare Statistics by Survival:")
    fare_survival = df.groupby('Survived')['Fare'].agg(['count', 'mean', 'median', 'std']).round(2)
    fare_survival.index = ['Did not survive', 'Survived']
    print(fare_survival)

print("\n" + "="*50)
print("Key Insights:")
if 'Sex' in df.columns and 'Survived' in df.columns:
    female_survival = df[df['Sex'] == 'female']['Survived'].mean()
    male_survival = df[df['Sex'] == 'male']['Survived'].mean()
    print(f"• Women had a {female_survival:.1%} survival rate vs {male_survival:.1%} for men")

if 'Pclass' in df.columns and 'Survived' in df.columns:
    first_class_survival = df[df['Pclass'] == 1]['Survived'].mean()
    third_class_survival = df[df['Pclass'] == 3]['Survived'].mean()
    print(f"• 1st class passengers: {first_class_survival:.1%} survival vs 3rd class: {third_class_survival:.1%}")

print("• This demonstrates how social factors affected survival during the disaster")
# Out:
# Survival Analysis:
#
# 1. Survival Rate by Gender:
#         Total  Survived  Survival_Rate
# Sex
# female    314       233          0.742
# male      577       109          0.189
#
# 2. Survival Rate by Passenger Class:
#            Total  Survived  Survival_Rate
# 1st Class    216       136          0.630
# 2nd Class    184        87          0.473
# 3rd Class    491       119          0.242
#
# 3. Age Statistics by Survival:
#                  count   mean  median    std
# Did not survive    424  30.63    28.0  14.17
# Survived           290  28.34    28.0  14.95
#
# 4. Fare Statistics by Survival:
#                  count   mean  median    std
# Did not survive    549  22.12    10.5  31.39
# Survived           342  48.40    26.0  66.60
#
# ...
# Key Insights:
# • Women had a 74.2% survival rate vs 18.9% for men
# • 1st class passengers: 63.0% survival vs 3rd class: 24.2%
# • This demonstrates how social factors affected survival during the disaster

# %% [markdown]
# ### 7. Correlation Analysis

# %%
# Calculate correlation matrix for numerical columns in Titanic dataset
numerical_columns = df.select_dtypes(include=[np.number]).columns.tolist()

# Remove PassengerId as it's just an identifier
if 'PassengerId' in numerical_columns:
    numerical_columns.remove('PassengerId')

if len(numerical_columns) >= 2:
    correlation_matrix = df[numerical_columns].corr()
    
    # Create a heatmap
    plt.figure(figsize=(10, 8))
    sns.heatmap(correlation_matrix, 
                annot=True, 
                cmap='coolwarm', 
                center=0,
                square=True,
                fmt='.3f',
                cbar_kws={'label': 'Correlation Coefficient'})
    plt.title('Correlation Matrix: Titanic Dataset Features', fontsize=14, fontweight='bold')
    plt.tight_layout()
    plt.show()
    
    print("Insights from Correlation Analysis:")
    
    # Survival correlations
    if 'Survived' in correlation_matrix.columns:
        print("\nCorrelations with Survival:")
        survival_corr = correlation_matrix['Survived'].drop('Survived').sort_values(key=abs, ascending=False)
        for feature, corr in survival_corr.items():
            direction = "positively" if corr > 0 else "negatively"
            strength = "strong" if abs(corr) > 0.3 else "moderate" if abs(corr) > 0.1 else "weak"
            print(f"• {feature}: {corr:.3f} ({strength} {direction} correlated)")
    
    # Other interesting correlations
    print(f"\nOther Notable Correlations:")
    if 'Fare' in correlation_matrix.columns and 'Pclass' in correlation_matrix.columns:
        fare_class_corr = correlation_matrix.loc['Fare', 'Pclass']
        print(f"• Fare and Passenger Class: {fare_class_corr:.3f}")
        print("  (Higher class passengers paid more, as expected)")
    
    if 'Age' in correlation_matrix.columns and 'Fare' in correlation_matrix.columns:
        age_fare_corr = correlation_matrix.loc['Age', 'Fare']
        print(f"• Age and Fare: {age_fare_corr:.3f}")
    
else:
    print("Not enough numerical columns for correlation analysis.")
    print(f"Available numerical columns: {numerical_columns}")

print(f"\n📊 Correlation helps us understand relationships between variables!")
print("🔍 Values close to +1 or -1 indicate strong relationships.")
# Out:
# Insights from Correlation Analysis:
#
# Correlations with Survival:
# • Pclass: -0.338 (strong negatively correlated)
# • Fare: 0.257 (moderate positively correlated)
# • Parch: 0.082 (weak positively correlated)
# • Age: -0.077 (weak negatively correlated)
# • SibSp: -0.035 (weak negatively correlated)
#
# Other Notable Correlations:
# • Fare and Passenger Class: -0.549
#   (Higher class passengers paid more, as expected)
# • Age and Fare: 0.096
#
# 📊 Correlation helps us understand relationships between variables!
# 🔍 Values close to +1 or -1 indicate strong relationships.

# %% [markdown]
# ### 8. Creating a Simple Scatter Plot

# %%
# Create scatter plots to explore relationships in the Titanic dataset
plt.figure(figsize=(15, 5))

# Scatter plot 1: Age vs Fare (colored by survival)
plt.subplot(1, 3, 1)
if 'Age' in df.columns and 'Fare' in df.columns and 'Survived' in df.columns:
    # Remove rows with missing Age or Fare values
    clean_data = df.dropna(subset=['Age', 'Fare'])
    
    # Create scatter plot with different colors for survivors vs non-survivors
    survivors = clean_data[clean_data['Survived'] == 1]
    non_survivors = clean_data[clean_data['Survived'] == 0]
    
    plt.scatter(non_survivors['Age'], non_survivors['Fare'], 
               alpha=0.6, c='red', label='Did not survive', s=30)
    plt.scatter(survivors['Age'], survivors['Fare'], 
               alpha=0.6, c='green', label='Survived', s=30)
    
    plt.xlabel('Age')
    plt.ylabel('Fare')
    plt.title('Age vs Fare by Survival')
    plt.legend()
    plt.grid(True, alpha=0.3)

# Scatter plot 2: Age vs Fare (colored by passenger class)
plt.subplot(1, 3, 2)
if 'Age' in df.columns and 'Fare' in df.columns and 'Pclass' in df.columns:
    clean_data = df.dropna(subset=['Age', 'Fare'])
    
    colors = ['red', 'blue', 'green']
    class_labels = ['1st Class', '2nd Class', '3rd Class']
    
    for i, pclass in enumerate([1, 2, 3]):
        class_data = clean_data[clean_data['Pclass'] == pclass]
        plt.scatter(class_data['Age'], class_data['Fare'], 
                   alpha=0.6, c=colors[i], label=class_labels[i], s=30)
    
    plt.xlabel('Age')
    plt.ylabel('Fare')
    plt.title('Age vs Fare by Passenger Class')
    plt.legend()
    plt.grid(True, alpha=0.3)

# Scatter plot 3: Family size vs Survival rate
plt.subplot(1, 3, 3)
if 'SibSp' in df.columns and 'Parch' in df.columns and 'Survived' in df.columns:
    # Create family size feature
    df_temp = df.copy()
    df_temp['FamilySize'] = df_temp['SibSp'] + df_temp['Parch'] + 1  # +1 for the passenger themselves
    
    # Calculate survival rate by family size
    family_survival = df_temp.groupby('FamilySize')['Survived'].agg(['count', 'mean']).reset_index()
    family_survival = family_survival[family_survival['count'] >= 5]  # Only show family sizes with 5+ passengers
    
    plt.scatter(family_survival['FamilySize'], family_survival['mean'], 
               s=family_survival['count']*10, alpha=0.7, c='purple')
    
    plt.xlabel('Family Size')
    plt.ylabel('Survival Rate')
    plt.title('Family Size vs Survival Rate')
    plt.grid(True, alpha=0.3)
    
    # Add text annotations for data points
    for _, row in family_survival.iterrows():
        plt.annotate(f'n={row["count"]}', 
                    (row['FamilySize'], row['mean']), 
                    xytext=(5, 5), textcoords='offset points', fontsize=8)

plt.tight_layout()
plt.show()

print("📊 These scatter plots reveal interesting patterns in the Titanic dataset!")
print("🔍 Key observations:")
print("• First plot: Notice how survival varies with age and fare")
print("• Second plot: Higher class passengers generally paid more")
print("• Third plot: Family size affected survival chances")
print("💡 Real-world data often reveals unexpected relationships!")
# Out:
# 📊 These scatter plots reveal interesting patterns in the Titanic dataset!
# 🔍 Key observations:
# • First plot: Notice how survival varies with age and fare
# • Second plot: Higher class passengers generally paid more
# • Third plot: Family size affected survival chances
# 💡 Real-world data often reveals unexpected relationships!

# %% [markdown]
# ## 🎯 Session 1 Key Takeaways
#
# ### What We Learned Today:
#
# ✅ **Data Science Definition** - Interdisciplinary field combining statistics, programming, and domain expertise
# ✅ **Python Ecosystem** - NumPy, Pandas, Matplotlib, Seaborn are essential tools
# ✅ **Environment Setup** - Anaconda, VS Code, or Google Colab options
# ✅ **Jupyter Notebooks** - Interactive computing environment for data science
# ✅ **Basic Operations** - Data creation, exploration, and visualization
# ✅ **First Analysis** - Correlation analysis and scatter plots
#
# ### Skills Practiced:
# - Importing libraries
# - Creating DataFrames
# - Basic data exploration
# - Creating visualizations
# - Correlation analysis
#
# ### Next Session Preview:
# **Session 2: Python Refresher for Data Science**
# - Data types and variables
# - Control flow and functions
# - List comprehensions
# - Error handling
# - Hands-on math and string operations

# %% [markdown]
# ## 🏠 Homework Assignment
#
# ### Practice Exercise:
#
# 1. **Install your preferred environment** (Anaconda, VS Code, or use Google Colab)
# 2. **Create a new notebook** and replicate the examples from today
# 3. **Modify the student dataset**:
#    - Add a new column called 'total_score' (math_score + science_score)
#    - Create a bar chart showing average total scores by major
#    - Find students who studied more than 5 hours
# 4. **Explore the data further**:
#    - What's the relationship between age and hours studied?
#    - Which major has the highest average science score?
#
# ### Resources for Learning:
# - [Pandas Documentation](https://pandas.pydata.org/docs/)
# - [Matplotlib Gallery](https://matplotlib.org/stable/gallery/)
# - [Jupyter Notebook Tutorial](https://jupyter-notebook.readthedocs.io/)
# - [Python for Data Science Handbook](https://jakevdp.github.io/PythonDataScienceHandbook/)
#
# ### Questions?
# Feel free to reach out via email or during our next session. Remember, the best way to learn data science is by doing!
#
# ---
#
# **Happy Coding! 🚀**
